# %%
from workflow import display_workflow_flowchart
display_workflow_flowchart() ## first version

# %%
from workflow import display_workflow_flowchart
display_workflow_flowchart()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[5], line 2
#       1 from workflow import display_workflow_flowchart
# ----> 2 display_workflow_flowchart()
#
# File ~/Downloads/SipControl-AI/langgraph_agents/workflow.py:523, in display_workflow_flowchart()
#     521 dot.edge('E', 'F5', 'Other Triggers')
#     522 dot.edge('E', 'F6', 'Unknown Trigger')
# --> 523 dot.edges(['F1G', 'F2G', 'F3G', 'F4G', 'F5G', 'F6G'])
#     524 dot.edge('G', 'H')
#     526 # Save and display
#
# File ~/miniforge3/envs/agent_py312/lib/python3.12/site-packages/graphviz/dot.py:255, in Dot.edges(self, tail_head_iter)
#     252 edge = self._edge_plain
#     253 quote = self._quote_edge
#     254 self.body += [edge(tail=quote(t), head=quote(h))
# --> 255               for t, h in tail_head_iter]
#
# ValueError: too many values to unpack (expected 2)
